# %%
import os

os.getcwd()
# Out:
# '/home/sheza/shahrzad/Uni/nlp/project/data/raw'

# %%
# %cd ../data/raw
os.getcwd()
# Out:
# [Errno 2] No such file or directory: '../data/raw'
# /home/sheza/shahrzad/Uni/nlp/project/data/raw
# '/home/sheza/shahrzad/Uni/nlp/project/data/raw'

# %%
# !wget https://zenodo.org/record/7879430/files/arguments-test-nahjalbalagha.tsv?download=1 -O arguments-test-nahjalbalagha.tsv
# !wget https://zenodo.org/record/7879430/files/arguments-test.tsv?download=1 -O arguments-test.tsv
# !wget https://zenodo.org/record/7879430/files/arguments-training.tsv?download=1 -O arguments-training.tsv
# !wget https://zenodo.org/record/7879430/files/arguments-validation-zhihu.tsv?download=1 -O arguments-validation-zhihu.tsv
# !wget https://zenodo.org/record/7879430/files/arguments-validation.tsv?download=1 -O arguments-validation.tsv
# !wget https://zenodo.org/record/7879430/files/labels-test-nahjalbalagha.tsv?download=1 -O labels-test-nahjalbalagha.tsv
# !wget https://zenodo.org/record/7879430/files/labels-test-nyt.tsv?download=1 -O labels-test-nyt.tsv
# !wget https://zenodo.org/record/7879430/files/labels-test.tsv?download=1 -O labels-test.tsv
# !wget https://zenodo.org/record/7879430/files/labels-training.tsv?download=1 -O labels-training.tsv
# !wget https://zenodo.org/record/7879430/files/labels-validation-zhihu.tsv?download=1 -O labels-validation-zhihu.tsv
# !wget https://zenodo.org/record/7879430/files/labels-validation.tsv?download=1 -O labels-validation.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-a.tsv?download=1 -O meta-arguments-a.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-c.tsv?download=1 -O meta-arguments-c.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-d.tsv?download=1 -O meta-arguments-d.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-e.tsv?download=1 -O meta-arguments-e.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-f.tsv?download=1 -O meta-arguments-f.tsv
# !wget https://zenodo.org/record/7879430/files/meta-arguments-g.tsv?download=1 -O meta-arguments-g.tsv
# !wget https://zenodo.org/record/7879430/files/value-categories.json?download=1 -O value-categories.json
# Out:
# --2023-06-07 11:11:33--  https://zenodo.org/record/7879430/files/arguments-test-nahjalbalagha.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45860 (45K) [application/octet-stream]
# Saving to: ‘arguments-test-nahjalbalagha.tsv’
#
# arguments-test-nahj 100%[===================>]  44.79K  --.-KB/s    in 0.08s
#
# 2023-06-07 11:11:34 (536 KB/s) - ‘arguments-test-nahjalbalagha.tsv’ saved [45860/45860]
#
# --2023-06-07 11:11:34--  https://zenodo.org/record/7879430/files/arguments-test.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 290185 (283K) [application/octet-stream]
# Saving to: ‘arguments-test.tsv’
#
# arguments-test.tsv  100%[===================>] 283.38K   716KB/s    in 0.4s
#
# 2023-06-07 11:11:36 (716 KB/s) - ‘arguments-test.tsv’ saved [290185/290185]
#
# --2023-06-07 11:11:36--  https://zenodo.org/record/7879430/files/arguments-training.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1012498 (989K) [application/octet-stream]
# Saving to: ‘arguments-training.tsv’
#
# arguments-training. 100%[===================>] 988.77K   593KB/s    in 1.7s
#
# 2023-06-07 11:11:39 (593 KB/s) - ‘arguments-training.tsv’ saved [1012498/1012498]
#
# --2023-06-07 11:11:39--  https://zenodo.org/record/7879430/files/arguments-validation-zhihu.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22082 (22K) [application/octet-stream]
# Saving to: ‘arguments-validation-zhihu.tsv’
#
# arguments-validatio 100%[===================>]  21.56K  --.-KB/s    in 0s
#
# 2023-06-07 11:11:40 (43.4 MB/s) - ‘arguments-validation-zhihu.tsv’ saved [22082/22082]
#
# --2023-06-07 11:11:41--  https://zenodo.org/record/7879430/files/arguments-validation.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362608 (354K) [application/octet-stream]
# Saving to: ‘arguments-validation.tsv’
#
# arguments-validatio 100%[===================>] 354.11K   676KB/s    in 0.5s
#
# 2023-06-07 11:11:42 (676 KB/s) - ‘arguments-validation.tsv’ saved [362608/362608]
#
# --2023-06-07 11:11:42--  https://zenodo.org/record/7879430/files/labels-test-nahjalbalagha.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13485 (13K) [application/octet-stream]
# Saving to: ‘labels-test-nahjalbalagha.tsv’
#
# labels-test-nahjalb 100%[===================>]  13.17K  --.-KB/s    in 0s
#
# 2023-06-07 11:11:43 (167 MB/s) - ‘labels-test-nahjalbalagha.tsv’ saved [13485/13485]
#
# --2023-06-07 11:11:43--  https://zenodo.org/record/7879430/files/labels-test-nyt.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4132 (4.0K) [application/octet-stream]
# Saving to: ‘labels-test-nyt.tsv’
#
# labels-test-nyt.tsv 100%[===================>]   4.04K  --.-KB/s    in 0s
#
# 2023-06-07 11:11:45 (777 MB/s) - ‘labels-test-nyt.tsv’ saved [4132/4132]
#
# --2023-06-07 11:11:45--  https://zenodo.org/record/7879430/files/labels-test.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74444 (73K) [application/octet-stream]
# Saving to: ‘labels-test.tsv’
#
# labels-test.tsv     100%[===================>]  72.70K  --.-KB/s    in 0.09s
#
# 2023-06-07 11:11:46 (813 KB/s) - ‘labels-test.tsv’ saved [74444/74444]
#
# --2023-06-07 11:11:46--  https://zenodo.org/record/7879430/files/labels-training.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253843 (248K) [application/octet-stream]
# Saving to: ‘labels-training.tsv’
#
# labels-training.tsv 100%[===================>] 247.89K   608KB/s    in 0.4s
#
# 2023-06-07 11:11:48 (608 KB/s) - ‘labels-training.tsv’ saved [253843/253843]
#
# --2023-06-07 11:11:48--  https://zenodo.org/record/7879430/files/labels-validation-zhihu.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5072 (5.0K) [application/octet-stream]
# Saving to: ‘labels-validation-zhihu.tsv’
#
# labels-validation-z 100%[===================>]   4.95K  --.-KB/s    in 0s
#
# 2023-06-07 11:11:49 (920 MB/s) - ‘labels-validation-zhihu.tsv’ saved [5072/5072]
#
# --2023-06-07 11:11:49--  https://zenodo.org/record/7879430/files/labels-validation.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89484 (87K) [application/octet-stream]
# Saving to: ‘labels-validation.tsv’
#
# labels-validation.t 100%[===================>]  87.39K  --.-KB/s    in 0.1s
#
# 2023-06-07 11:11:51 (891 KB/s) - ‘labels-validation.tsv’ saved [89484/89484]
#
# --2023-06-07 11:11:51--  https://zenodo.org/record/7879430/files/meta-arguments-a.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262899 (257K) [application/octet-stream]
# Saving to: ‘meta-arguments-a.tsv’
#
# meta-arguments-a.ts 100%[===================>] 256.74K   195KB/s    in 1.3s
#
# 2023-06-07 11:11:53 (195 KB/s) - ‘meta-arguments-a.tsv’ saved [262899/262899]
#
# --2023-06-07 11:11:53--  https://zenodo.org/record/7879430/files/meta-arguments-c.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26255 (26K) [application/octet-stream]
# Saving to: ‘meta-arguments-c.tsv’
#
# meta-arguments-c.ts 100%[===================>]  25.64K  --.-KB/s    in 0.004s
#
# 2023-06-07 11:11:55 (5.77 MB/s) - ‘meta-arguments-c.tsv’ saved [26255/26255]
#
# --2023-06-07 11:11:55--  https://zenodo.org/record/7879430/files/meta-arguments-d.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32172 (31K) [application/octet-stream]
# Saving to: ‘meta-arguments-d.tsv’
#
# meta-arguments-d.ts 100%[===================>]  31.42K  --.-KB/s    in 0.005s
#
# 2023-06-07 11:11:56 (6.15 MB/s) - ‘meta-arguments-d.tsv’ saved [32172/32172]
#
# --2023-06-07 11:11:56--  https://zenodo.org/record/7879430/files/meta-arguments-e.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 144221 (141K) [application/octet-stream]
# Saving to: ‘meta-arguments-e.tsv’
#
# meta-arguments-e.ts 100%[===================>] 140.84K   756KB/s    in 0.2s
#
# 2023-06-07 11:11:58 (756 KB/s) - ‘meta-arguments-e.tsv’ saved [144221/144221]
#
# --2023-06-07 11:11:59--  https://zenodo.org/record/7879430/files/meta-arguments-f.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 541604 (529K) [application/octet-stream]
# Saving to: ‘meta-arguments-f.tsv’
#
# meta-arguments-f.ts 100%[===================>] 528.91K   532KB/s    in 1.0s
#
# 2023-06-07 11:12:01 (532 KB/s) - ‘meta-arguments-f.tsv’ saved [541604/541604]
#
# --2023-06-07 11:12:01--  https://zenodo.org/record/7879430/files/meta-arguments-g.tsv?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7462 (7.3K) [application/octet-stream]
# Saving to: ‘meta-arguments-g.tsv’
#
# meta-arguments-g.ts 100%[===================>]   7.29K  --.-KB/s    in 0s
#
# 2023-06-07 11:12:02 (397 MB/s) - ‘meta-arguments-g.tsv’ saved [7462/7462]
#
# --2023-06-07 11:12:02--  https://zenodo.org/record/7879430/files/value-categories.json?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10289 (10K) [text/plain]
# Saving to: ‘value-categories.json’
#
# value-categories.js 100%[===================>]  10.05K  --.-KB/s    in 0s
#
# 2023-06-07 11:12:04 (179 MB/s) - ‘value-categories.json’ saved [10289/10289]

# %%
# %cd ../../src/nyt-downloader
os.getcwd()
# Out:
# /home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader
# '/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader'

# %%
# !pip3 install -r requirements.txt
# !spacy download en_core_web_sm
# !python3 nyt-downloader.py --input-file nyt01-spans.tsv --output-file ../data/raw/arguments-test-nyt.tsv
# !sha256sum --check arguments-test-nyt.sha256
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spacy
#   Downloading spacy-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 795.1 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /home/sheza/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.28.1)
# Collecting requests_html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /home/sheza/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.0.2)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 385.6 kB/s eta 0:00:0000:0100:01
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy->-r requirements.txt (line 1)) (59.6.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 KB 496.9 kB/s eta 0:00:00a 0:00:01
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 KB 646.8 kB/s eta 0:00:0000:0100:01
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (913 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.3/913.3 KB 830.9 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy->-r requirements.txt (line 1)) (21.3)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 KB 178.4 kB/s eta 0:00:00a 0:00:01
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 KB 261.3 kB/s eta 0:00:0000:0100:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 814.9 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: jinja2 in /home/sheza/.local/lib/python3.10/site-packages (from spacy->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sheza/.local/lib/python3.10/site-packages (from spacy->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sheza/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 2)) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->-r requirements.txt (line 2)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sheza/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 2)) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sheza/.local/lib/python3.10/site-packages (from requests->-r requirements.txt (line 2)) (2.1.0)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 KB 432.3 kB/s eta 0:00:000:0100:01
# Collecting pyquery
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 234.6 kB/s eta 0:00:00 0:00:01
# Collecting w3lib
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sheza/.local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/sheza/.local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 4)) (2022.1)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sheza/.local/lib/python3.10/site-packages (from packaging>=20.0->spacy->-r requirements.txt (line 1)) (3.0.9)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/lib/python3/dist-packages (from pyppeteer>=0.0.14->requests_html->-r requirements.txt (line 3)) (4.6.4)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 KB 343.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 4)) (1.16.0)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 878.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy->-r requirements.txt (line 1)) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sheza/.local/lib/python3.10/site-packages (from jinja2->spacy->-r requirements.txt (line 1)) (2.1.1)
# Collecting lxml>=2.1
#   Using cached lxml-4.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# Collecting cssselect>=1.2.0
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Building wheels for collected packages: bs4, parse
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=c904c1984e081c3b543112f6e6843cca9310c635039d09214a4fc483201f0588
#   Stored in directory: /home/sheza/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=412e4e39f7e17705add4b2329b159f0721e3d568c39d8b1c8572366c4da4b8c2
#   Stored in directory: /home/sheza/.cache/pip/wheels/70/4b/f0/eaf5a8de646d8676dc25caa01949b9f9d883b8fa2efb435bc3
# Successfully built bs4 parse
# Installing collected packages: pyee, parse, fake-useragent, cymem, appdirs, websockets, wasabi, w3lib, typing-extensions, typer, spacy-loggers, spacy-legacy, soupsieve, murmurhash, lxml, langcodes, et-xmlfile, cssselect, catalogue, blis, srsly, pyquery, pyppeteer, pydantic, preshed, pathy, openpyxl, beautifulsoup4, confection, bs4, thinc, requests_html, spacy
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.2 blis-0.7.9 bs4-0.0.1 catalogue-2.0.8 confection-0.0.4 cssselect-1.2.0 cymem-2.0.7 et-xmlfile-1.1.0 fake-useragent-1.1.3 langcodes-3.3.0 lxml-4.9.2 murmurhash-1.0.9 openpyxl-3.1.2 parse-1.19.0 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.8 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests_html-0.10.0 soupsieve-2.4.1 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 thinc-8.1.10 typer-0.7.0 typing-extensions-4.6.3 w3lib-2.1.1 wasabi-1.1.2 websockets-10.4
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 818.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/sheza/.local/lib/python3.10/site-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.8)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (59.6.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: jinja2 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/sheza/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sheza/.local/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/sheza/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.6.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sheza/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sheza/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sheza/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/sheza/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/sheza/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sheza/.local/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Downloading https://web.archive.org/web/20220806174520/https://www.nytimes.com/2020/09/17/opinion/coronavirus-vaccine-trials.html
# [INFO] Starting Chromium download.
# Traceback (most recent call last):
#   File "/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader/nyt-downloader.py", line 97, in main
#     articles[a] = read_from_cache(a)
#   File "/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader/nyt-downloader.py", line 34, in read_from_cache
#     raise FileNotFoundError()
# FileNotFoundError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader/nyt-downloader.py", line 135, in <module>
#     main()
#   File "/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader/nyt-downloader.py", line 101, in main
#     articles[a] = download_raw_article(a)
#   File "/home/sheza/shahrzad/Uni/nlp/project/src/nyt-downloader/nyt-downloader.py", line 47, in download_raw_article
#     r.html.render(timeout = 120)
#   File "/home/sheza/.local/lib/python3.10/site-packages/requests_html.py", line 586, in render
#     self.browser = self.session.browser  # Automatically create a event loop and browser
#   File "/home/sheza/.local/lib/python3.10/site-packages/requests_html.py", line 730, in browser
#     self._browser = self.loop.run_until_complete(super().browser)
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 646, in run_until_complete
#     return future.result()
#   File "/home/sheza/.local/lib/python3.10/site-packages/requests_html.py", line 714, in browser
#     self._browser = await pyppeteer.launch(ignoreHTTPSErrors=not(self.verify), headless=True, args=self.__browser_args)
#   File "/home/sheza/.local/lib/python3.10/site-packages/pyppeteer/launcher.py", line 307, in launch
#     return await Launcher(options, **kwargs).launch()
#   File "/home/sheza/.local/lib/python3.10/site-packages/pyppeteer/launcher.py", line 120, in __init__
#     download_chromium()
#   File "/home/sheza/.local/lib/python3.10/site-packages/pyppeteer/chromium_downloader.py", line 139, in download_chromium
#     extract_zip(download_zip(get_url()), DOWNLOADS_FOLDER / REVISION)
#   File "/home/sheza/.local/lib/python3.10/site-packages/pyppeteer/chromium_downloader.py", line 83, in download_zip
#     raise OSError(f'Chromium downloadable not found at {url}: ' f'Received {r.data.decode()}.\n')
# OSError: Chromium downloadable not found at https://storage.googleapis.com/chromium-browser-snapshots/Linux_x64/588429/chrome-linux.zip: Received <?xml version='1.0' encoding='UTF-8'?><Error><Code>AccessDenied</Code><Message>Access denied.</Message><Details>We're sorry, but this service is not available in your location</Details></Error>.
#
# sha256sum: arguments-test-nyt.tsv: No such file or directory
# arguments-test-nyt.tsv: FAILED open or read
# sha256sum: WARNING: 1 listed file could not be read
